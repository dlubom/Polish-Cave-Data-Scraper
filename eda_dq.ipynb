# %%
import pandas as pd

pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)
pd.set_option("display.width", 100)
pd.set_option("max_colwidth", 100)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("EDA_DQ_Caves").getOrCreate()

df = spark.read.parquet("caves_transformed.parquet")

df.createOrReplaceTempView("caves_view")
# Out:
# 24/11/12 14:50:38 WARN Utils: Your hostname, pxpl-lp-dl2 resolves to a loopback address: 127.0.1.1; using 10.58.74.200 instead (on interface wlp0s20f3)
# 24/11/12 14:50:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/12 14:50:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/11/12 14:50:40 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 24/11/12 14:50:40 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 24/11/12 14:50:40 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 24/11/12 14:50:40 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 24/11/12 14:50:45 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- other_names: string (nullable = true)
#  |-- inventory_number: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- coordinates_wgs84: string (nullable = true)
#  |-- commune: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- province: string (nullable = true)
#  |-- land_owner: string (nullable = true)
#  |-- protection_basis: string (nullable = true)
#  |-- entrance_exposition: string (nullable = true)
#  |-- other_entrances: string (nullable = true)
#  |-- absolute_height_masl: float (nullable = true)
#  |-- relative_height_m: float (nullable = true)
#  |-- depth_m: float (nullable = true)
#  |-- elevation_difference_m: float (nullable = true)
#  |-- denivelation_m: float (nullable = true)
#  |-- length_m: float (nullable = true)
#  |-- estimated_length_m: float (nullable = true)
#  |-- horizontal_extent_m: float (nullable = true)
#  |-- geographical_location: string (nullable = true)
#  |-- entrance_access_description: string (nullable = true)
#  |-- cave_description: string (nullable = true)
#  |-- research_history: string (nullable = true)
#  |-- exploration_history: string (nullable = true)
#  |-- documentation_history: string (nullable = true)
#  |-- destroyed_unavailable_or_unfound: string (nullable = true)
#  |-- literature: string (nullable = true)
#  |-- archival_materials: string (nullable = true)
#  |-- authors_of_study: string (nullable = true)
#  |-- editorial: string (nullable = true)
#  |-- state_in_year: string (nullable = true)
#  |-- graphics_photos: string (nullable = true)
#  |-- object_in_geostanowiska_service: string (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- metadata: struct (nullable = true)
#  |    |    |    |-- graphics_id: long (nullable = true)
#  |    |    |    |-- mime: string (nullable = true)
#  |    |    |    |-- graphics: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- creation_date: string (nullable = true)
#  |    |    |    |-- creation_date_string: string (nullable = true)
#  |    |    |    |-- graphics_name: string (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- author_name: string (nullable = true)
#  |    |    |    |-- cave_id: long (nullable = true)
#  |    |    |    |-- cave_name: string (nullable = true)
#  |    |    |    |-- graphics_type_id: long (nullable = true)
#  |    |    |    |-- graphics_type_name: string (nullable = true)
#  |    |    |    |-- inventory_number: string (nullable = true)
#  |    |    |    |-- region: string (nullable = true)
#  |    |    |    |-- maxWidth: long (nullable = true)
#  |    |    |    |-- maxHeight: long (nullable = true)
#  |    |    |    |-- fileUpload: string (nullable = true)
#  |    |    |    |-- Authors: string (nullable = true)
#  |    |    |    |-- GraphicsTypes: string (nullable = true)
#  |    |    |-- image_path: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |-- cave_id: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)

# %%
df.limit(1).toPandas()
# Out:
#                name  \
# 0  Grota w Mechowej
#
#                                                                                            other_names  \
# 0  Mechauer Höhle, Grota w Mechowej, Jaskinia w Mechowej koło Pucka, "Groty Mechowskie",  "Grota Me...
#
#   inventory_number      region                 coordinates_wgs84             commune district  \
# 0            NP-01  Niż Polski  λ: 18°17′04,80″, φ: 54°42′48,65″  Puck (gm. wiejska)    pucki
#
#     province                                   land_owner                    protection_basis  \
# 0  pomorskie  Komunalny\n|                Pomnik przyrody  Dz. Urz. WRN nr 1, poz. 4, 1955 r.
#
#   entrance_exposition other_entrances  absolute_height_masl  relative_height_m  depth_m  \
# 0                   S                                  56.0                NaN      0.0
#
#    elevation_difference_m  denivelation_m  length_m  estimated_length_m  horizontal_extent_m  \
# 0                     0.0             0.0      61.0                 NaN                  NaN
#
#                                                                                  geographical_location  \
# 0  Jaskinia jest usytuowana we wschodniej części miejscowości Mechowo (w użyciu była też nazwa - Me...
#
#                                                                            entrance_access_description  \
# 0  Dojazd i dojście do jaskini są oznakowane (drogowskazy, turystyczny "szlak Grot Mechowskich").\n...
#
#                                                                                       cave_description  \
# 0  Jaskinia posiada kilka otworów, z których dwa (na planie nr 1 i 2) stanowią początek (1) i konie...
#
#   research_history  \
# 0
#
#                                                                                    exploration_history  \
# 0  Jaskinia została po raz pierwszy opisana i skartowana przez Radcę Miasta Gdańska Kleefelda w 181...
#
#                                                                                  documentation_history  \
# 0  Dokładną inwentaryzację jaskini, łącznie ze sporządzeniem jej planu, wykonał K. Kowalski w lipcu...
#
#   destroyed_unavailable_or_unfound  \
# 0                              Nie
#
#                                                                                             literature  \
# 0  Kleefeld, Wrede 1829 (opis i plan jaskini, opis skał, okazów paleontologicznych i minerałów); Sł...
#
#   archival_materials          authors_of_study        editorial state_in_year    graphics_photos  \
# 0                     Jan Urban, Janusz Baryła  Jerzy Grodzicki          2013  otworyplanwnętrze
#
#   object_in_geostanowiska_service  \
# 0                   Geostanowisko
#
#                                                                                                 images  \
# 0  [((15011, image/jpeg, [], /Date(1641769200000)/, 2022-01-10, otwory, 0, Polonius Adam, 0, None, ...
#
#   cave_id   latitude  longitude
# 0  000390  54.713514  18.284667

# %%
df.where("name LIKE '%test%' OR cave_description LIKE 'Lorem ipsum%'").toPandas()
# Out:
#                      name other_names inventory_number  region                 coordinates_wgs84  \
# 0  TEST1-obiekt do testów                    ZZZ-9.9.9  Sudety
# 1  TEST2-obiekt do testów  alias test        ZZZ-9.9.8  Sudety  λ: 20°43′06,80″, φ: 53°56′24,00″
#
#                            commune    district             province     land_owner  \
# 0            Kościan (gm. wiejska)  kościański        wielkopolskie  Skarb Państwa
# 1  Jeziorany (gm. miejsko-wiejska)  olsztyński  warmińsko-mazurskie       Prywatny
#
#   protection_basis entrance_exposition other_entrances  absolute_height_masl  relative_height_m  \
# 0                                    E  aaa 04.01.2023            123.400002               12.0
# 1                                                  aaa                   NaN                NaN
#
#    depth_m  elevation_difference_m  denivelation_m  length_m  estimated_length_m  \
# 0     10.0                     2.0            12.0     123.0                 NaN
# 1      NaN                     NaN             NaN       NaN                 NaN
#
#    horizontal_extent_m geographical_location  \
# 0                  NaN        aaa 04.01.2023
# 1                  NaN                   aaa
#
#                                                                            entrance_access_description  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet\n\nLorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at ...
#
#                                                                                       cave_description  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#                                                                                       research_history  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#                                                                                    exploration_history  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#                                                                                  documentation_history  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#   destroyed_unavailable_or_unfound  \
# 0                              Nie
# 1                              Nie
#
#                                                                                             literature  \
# 0  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#                                                                                     archival_materials  \
# 0
# 1  Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec at vestibulum odio. Phasellus feu...
#
#   authors_of_study      editorial state_in_year                graphics_photos  \
# 0     CBDG PIG-PIB  Ewa Machalska          2021  otwór-test2testtest luty 2024
# 1    Ewa Machalska  Ewa Machalska          2015                     otwór-test
#
#   object_in_geostanowiska_service  \
# 0                            None
# 1                            None
#
#                                                                                                 images  \
# 0  [((15090, image/jpeg, [], /Date(1652220000000)/, 2022-05-11, otwór-test2, 0, Machalska Ewa, 0, N...
# 1  [((15070, image/jpeg, [], /Date(1651615200000)/, 2022-05-04, otwór-test, 0, Machalska Ewa, 0, No...
#
#   cave_id  latitude  longitude
# 0  010569       NaN        NaN
# 1  011054     53.94  20.718556

# %%
spark.stop()
